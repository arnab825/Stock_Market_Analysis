# %% [markdown]
# ## 📈 Stock Market Analysis  Apple VS Microsoft
#
# ## 🎯 Objective
# **Explore stock market trends, visualize patterns, and predict future stock prices.**
#
# ## 🛠 Tech Used
# - 🐍 **Python** (Pandas, NumPy, Matplotlib, Seaborn)
# - 🤖 **Machine Learning** (Linear Regression, Sklearn)
#
# ## 📂 Dataset
# The dataset includes:
# - 📅 **Date**
# - 🏢 **Stock Name**
# - 📊 **Open, High, Low, Close Prices**
# - 🔄 **Volume & Moving Averages**
#
# ## 🔑 Key Insights
# - 📉 **Stock price trends over time**
# - 📊 **Volatility & correlation analysis**
# - 🔮 **Predictive analysis using regression models**
#
# ## ✅ Use Case
# Helps investors make **data-driven financial decisions** and understand market trends.
#
# ## 🔮 Conclusion
# The analysis provided valuable insights into **stock price movements, volatility, and future trends.**
# Further improvements could include **advanced ML models & external economic indicators** for better predictions.

# %% [markdown]
# ### Python Packages

# %%
# Installing python packages for data visualization
# %pip install numpy
# %pip install seaborn
# %pip install matplotlib.pyplot
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
#
# ...
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement matplotlib.pyplot (from versions: none)
# ERROR: No matching distribution found for matplotlib.pyplot
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Importing Numpy ,Pandas , Seaborn , Matplotlib , Pandas , Linear Regression and Time Delta

# %%
# import 4 libraries
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression
from datetime import timedelta

# creating the data frame
df=pd.read_excel('stock_data.xlsx')

# displaying the data frame
df
# Out:
#          Date Stock_Name          Open         Close   Volume
# 0  2024-01-01      Apple    149.867312    150.993428  4719393
# 1  2024-01-02      Apple    299.883738    300.716900  3014484
# 2  2024-01-03      Apple    451.332479    452.012277  3937629
# 3  2024-01-04      Apple    604.051914    605.058336  3457184
# 4  2024-01-05      Apple    752.675665    754.590030  4143963
# ..        ...        ...           ...           ...      ...
# 95 2024-02-15  Microsoft  13800.256699  13801.122683  2532875
# 96 2024-02-16  Microsoft  14099.755408  14101.714924  4757938
# 97 2024-02-17  Microsoft  14401.147388  14402.237034  1448982
# 98 2024-02-18  Microsoft  14700.409191  14702.247261  2172622
# 99 2024-02-19  Microsoft  15000.331379  15001.778087  3503771
#
# [100 rows x 5 columns]

# %% [markdown]
# ### Display First 10 rows

# %%
# display first 10 rows
# print(df.head(10))
df.head(10)
# Out:
#         Date Stock_Name         Open        Close   Volume
# 0 2024-01-01      Apple   149.867312   150.993428  4719393
# 1 2024-01-02      Apple   299.883738   300.716900  3014484
# 2 2024-01-03      Apple   451.332479   452.012277  3937629
# 3 2024-01-04      Apple   604.051914   605.058336  3457184
# 4 2024-01-05      Apple   752.675665   754.590030  4143963
# 5 2024-01-06      Apple   903.136951   904.121756  2418175
# 6 2024-01-07      Apple  1056.001996  1057.280181  4806688
# 7 2024-01-08      Apple  1207.260522  1208.815051  4895748
# 8 2024-01-09      Apple  1356.830658  1357.876102  3976763
# 9 2024-01-10      Apple  1507.003549  1508.961222  4317564

# %%
# display the information
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        100 non-null    datetime64[ns]
#  1   Stock_Name  100 non-null    object
#  2   Open        100 non-null    float64
#  3   Close       100 non-null    float64
#  4   Volume      100 non-null    int64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(1)
# memory usage: 4.0+ KB
# None

# %%
# to get summary information
# print(df.describe())
df.describe()
# Out:
#                       Date          Open         Close        Volume
# count                  100    100.000000    100.000000  1.000000e+02
# mean   2024-01-25 12:00:00   5734.734021   5735.963330  3.251294e+06
# min    2024-01-01 00:00:00    149.867312    150.993428  1.115294e+06
# 25%    2024-01-13 00:00:00   2658.837489   2660.131589  2.385171e+06
# 50%    2024-01-25 12:00:00   5094.212454   5095.658752  3.341872e+06
# 75%    2024-02-07 00:00:00   7579.529968   7580.715649  4.220990e+06
# max    2024-02-19 00:00:00  15000.331379  15001.778087  4.965988e+06
# std                    NaN   3940.927211   3940.937323  1.149109e+06

# %%
# check for missing values
print(df.isnull().sum())
# Out:
# Date          0
# Stock_Name    0
# Open          0
# Close         0
# Volume        0
# dtype: int64

# %%
# data cleaning and handle missing values
# Check for missing values
if df.isnull().values.any():
    print("Missing values found. Filling missing values with column means...")
    df.fillna(df.select_dtypes(include=[np.number]).mean(), inplace=True)
    print("Data cleaning has been successfully executed!\n")
else:
    print("No missing values found.")

# Display the DataFrame
print(df)
# Out:
# No missing values found.
#          Date Stock_Name          Open         Close   Volume
# 0  2024-01-01      Apple    149.867312    150.993428  4719393
# 1  2024-01-02      Apple    299.883738    300.716900  3014484
# 2  2024-01-03      Apple    451.332479    452.012277  3937629
# 3  2024-01-04      Apple    604.051914    605.058336  3457184
# 4  2024-01-05      Apple    752.675665    754.590030  4143963
# ..        ...        ...           ...           ...      ...
# 95 2024-02-15  Microsoft  13800.256699  13801.122683  2532875
# 96 2024-02-16  Microsoft  14099.755408  14101.714924  4757938
# 97 2024-02-17  Microsoft  14401.147388  14402.237034  1448982
# 98 2024-02-18  Microsoft  14700.409191  14702.247261  2172622
# 99 2024-02-19  Microsoft  15000.331379  15001.778087  3503771
#
# [100 rows x 5 columns]

# %%
#Removing Duplicates
# Check for duplicates
if df.duplicated().any():
    print("Duplicates found. Removing duplicates...")
    df.drop_duplicates(inplace=True)
    print("Data after removing duplicates:")
else:
    print("No duplicates found.")

# Display the DataFrame
print(df)
# Out:
# No duplicates found.
#          Date Stock_Name          Open         Close   Volume
# 0  2024-01-01      Apple    149.867312    150.993428  4719393
# 1  2024-01-02      Apple    299.883738    300.716900  3014484
# 2  2024-01-03      Apple    451.332479    452.012277  3937629
# 3  2024-01-04      Apple    604.051914    605.058336  3457184
# 4  2024-01-05      Apple    752.675665    754.590030  4143963
# ..        ...        ...           ...           ...      ...
# 95 2024-02-15  Microsoft  13800.256699  13801.122683  2532875
# 96 2024-02-16  Microsoft  14099.755408  14101.714924  4757938
# 97 2024-02-17  Microsoft  14401.147388  14402.237034  1448982
# 98 2024-02-18  Microsoft  14700.409191  14702.247261  2172622
# 99 2024-02-19  Microsoft  15000.331379  15001.778087  3503771
#
# [100 rows x 5 columns]

# %%
# Convert the Date column to a datetime format
df['Date'] = pd.to_datetime(df['Date'])

# Sort the DataFrame by the 'Date' column
# df.sort_values(by=['Date'], inplace=True)

# Reset the index to make it sequential
# df.reset_index(drop=True, inplace=True)

# Display the DataFrame
df.set_index("Date", inplace=True)
print(df)
# Out:
#            Stock_Name          Open         Close   Volume
# Date
# 2024-01-01      Apple    149.867312    150.993428  4719393
# 2024-01-01  Microsoft    299.636568    300.648168  2989173
# 2024-01-02      Apple    299.883738    300.716900  3014484
# 2024-01-02  Microsoft    599.207793    599.878003  4080761
# 2024-01-03      Apple    451.332479    452.012277  3937629
# ...               ...           ...           ...      ...
# 2024-02-17      Apple   7179.211350   7180.291453  1689944
# 2024-02-18  Microsoft  14700.409191  14702.247261  2172622
# 2024-02-18      Apple   7329.073595   7330.978690  1688105
# 2024-02-19      Apple   7476.746328   7477.452609  3610910
# 2024-02-19  Microsoft  15000.331379  15001.778087  3503771
#
# [100 rows x 4 columns]

# %% [markdown]
# ## Visualizing the Data

# %% [markdown]
# # 1️⃣ Stock Closing Prices Over Time 📈
# # 📌 Visualises the stock price trends over time for each stock.
# # 📌 Helps identify patterns, peaks, and downward trends.

# %%
#  1🏠 Plot stock closing prices over time

plt.figure(figsize=(12, 6))
for stock in df["Stock_Name"].unique():
    stock_data = df[df["Stock_Name"] == stock]
    plt.plot(stock_data.index, stock_data["Close"], label=stock)

plt.xlabel("Date")
plt.ylabel("Closing Price")
plt.title("Stock Closing Prices Over Time")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # 2️⃣ Market Share Analysis 📊
# # 📌 Shows the market share of different stocks based on their average closing prices.

# %%
# 2🌟 Market Share Analysis
plt.figure(figsize=(8, 8))
market_share = df.groupby("Stock_Name")["Close"].mean()
plt.pie(market_share, labels=market_share.index, autopct="%1.1f%%", startangle=140, colors=sb.color_palette("muted"))
plt.title("Market Share Based on Average Closing Price")
plt.show()

# %% [markdown]
# # 3️⃣ Moving Average (Trend Analysis) 🔄
# # 📌 Calculates a 7-day moving average to smooth out fluctuations and highlight trends.

# %%
# 3📊 Moving Average (Trend Analysis)
df["Moving_Avg_7"] = df.groupby("Stock_Name")["Close"].transform(lambda x: x.rolling(window=7).mean())
plt.figure(figsize=(12, 6))
for stock in df["Stock_Name"].unique():
    stock_data = df[df["Stock_Name"] == stock]
    plt.plot(stock_data.index, stock_data["Moving_Avg_7"], label=f"{stock} 7-day MA")

plt.xlabel("Date")
plt.ylabel("Price")
plt.title("7-Day Moving Average of Closing Prices")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # 4️⃣ Daily Price Change (Volatility Analysis) ⚡
# # 📌 Measures daily percentage change to understand stock volatility.

# %%
# 4📉 Daily Price Change (Volatility Indicator)
# Reset index to ensure unique labels
df = df.reset_index().drop_duplicates(subset='Date').set_index('Date')
df["Daily_Change"] = df["Close"].pct_change() * 100
plt.figure(figsize=(12, 6))
sb.boxplot(x="Stock_Name", y="Daily_Change", data=df)
plt.xlabel("Stock Name")
plt.ylabel("Daily % Change")
plt.title("Stock Volatility Analysis")
plt.grid()
plt.show()

# %% [markdown]
# # 5️⃣ Heatmap: Correlation Matrix 🌡️
# 📌 Shows relationships between stock features (e.g., open price, close price, volume).

# %%
# 5🌎 Heatmap: Correlation Matrix
plt.figure(figsize=(10, 6))
corr_matrix = df[["Open", "Close", "Volume", "Daily_Change"]].corr()
sb.heatmap(corr_matrix, annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Heatmap of Stock Data")
plt.show()

# %% [markdown]
# # 6️⃣ Distribution of Closing Prices 📊
# # 📌 Analyses how closing prices are distributed for different stocks.

# %%
# 6📊 Distribution of Closing Prices
plt.figure(figsize=(12, 6))
sb.histplot(df, x="Close", hue="Stock_Name", kde=True, bins=30, palette="Set2")
plt.xlabel("Closing Price")
plt.ylabel("Frequency")
plt.title("Distribution of Closing Prices")
plt.grid()
plt.show()

# %%
print(df["PL_Label"].value_counts())  # Check if "Loss" is even present
# Out:
# PL_Label
# Profit    50
# Name: count, dtype: int64

# %%
# Randomly select 20% of the dataset and artificially reduce the closing price to create loss cases
df.loc[df.sample(frac=0.2).index, "Close"] = df["Open"] - np.random.uniform(1, 10, size=len(df))

# Calculate the profit or loss for each stock
df["Profit/Loss"] = df["Close"] - df["Open"]

# Label the stock as "Profit" if closing price is greater than or equal to opening price, otherwise label as "Loss"
df["PL_Label"] = np.where(df["Profit/Loss"] >= 0, "Profit", "Loss")

# %% [markdown]
# # 7️⃣ Scatter Plot: Profit vs Loss 💰📉
# # 📌 Distinguishes profitable and loss-making stocks using a scatter plot.

# %%
# 7📈 Scatter Plot: Profit vs Loss
df["Profit/Loss"] = df["Close"] - df["Open"]
df["PL_Label"] = np.where(df["Profit/Loss"] >= 0, "Profit", "Loss")
plt.figure(figsize=(10, 6))
sb.scatterplot(x=df["Open"], y=df["Close"], hue=df["PL_Label"], palette={"Profit": "green", "Loss": "red"})
plt.xlabel("Opening Price")
plt.ylabel("Closing Price")
plt.title("Scatter Plot: Profit vs Loss")
plt.grid()
plt.show()

# %% [markdown]
# # 8️⃣ Predictive Analysis: Next 30 Days Forecast 🔮📅
# # 📌 Generates a future price trend based on historical data.

# %%
# 8📈 Predictive Analysis (30-day forecast using Linear Regression)
df_reset = df.reset_index()
df_reset["Days"] = (df_reset["Date"] - df_reset["Date"].min()).dt.days

# Train model
model = LinearRegression()
X = df_reset[["Days"]]
y = df_reset["Close"]
model.fit(X, y)

# Generate future dates
future_days = np.array(range(df_reset["Days"].max() + 1, df_reset["Days"].max() + 31)).reshape(-1, 1)
future_dates = [df_reset["Date"].max() + timedelta(days=i) for i in range(1, 31)]
predictions = model.predict(future_days)

# Plot predictions
plt.figure(figsize=(12, 6))
plt.plot(df_reset["Date"], df_reset["Close"], label="Actual Data")
plt.plot(future_dates, predictions, label="Predicted", linestyle="dashed", color="red")
plt.xlabel("Date")
plt.ylabel("Closing Price")
plt.title("Stock Price Prediction for Next 30 Days")
plt.legend()
plt.grid()
plt.show()
# Out:
# c:\Users\rarna\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ### 🎯 Final Thoughts
# ### ✅ Comprehensive stock analysis using multiple visualisations.
# ### ✅ Covers market trends, volatility, profit/loss, and predictive forecasting.
# ### ✅ Ensures clear, insightful, and visually appealing data interpretation.
